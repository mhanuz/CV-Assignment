# %%
import cv2 as cv
import matplotlib.pyplot as plt
# loaded by opencv
image = cv.imread('images/sunflower.jfif')
# show by matplotlib
plt.imshow(image)

# %% [markdown]
# OpenCV follows the BGR color channels
# whereas matplotlib follows the RGB color channels,
# Red and Blue color swap,
# that's why the color diffrence is arisen.
